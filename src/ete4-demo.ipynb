# %%
from random import random
from ete4 import Tree

t = Tree()
t.populate(100, dist_fn=random, support_fn=random)

# %%
t.explore(verbose=True)
# Out:
# Using existing server.
# Explorer available at http://127.0.0.1:5000
# gio: http://127.0.0.1:5000: Operation not supported

# %%
t.explore(show_popup_props=["dist"])
# Out:
# Using existing server.
# Explorer available at http://127.0.0.1:5000
# gio: http://127.0.0.1:5000: Operation not supported

# %%
from ete4 import Tree
from ete4.smartview import Layout

t = Tree()
t.populate(20)

layout = Layout(name="I am a layout doing nothing")
t.explore(layouts=[layout])
# Out:
# Using existing server.
# Explorer available at http://127.0.0.1:5000
# gio: http://127.0.0.1:5000: Operation not supported

# %%
from ete4 import Tree
from ete4.smartview import Layout

t = Tree()
t.populate(20)

layout = Layout(name='my layout',
                draw_tree={'node-height-min': 100})

t.explore(layouts=[layout])
# Out:
# Using existing server.
# Explorer available at http://127.0.0.1:5000
# gio: http://127.0.0.1:5000: Operation not supported

# %%
from ete4 import Tree
import random

t = Tree()
random.seed(42)  # set seed if we want a reproducible result
t.populate(100, dist_fn=random.random, support_fn=lambda: 1)
t.explore()
# Out:
# Using existing server.
# Explorer available at http://127.0.0.1:5000
# gio: http://127.0.0.1:5000: Operation not supported
